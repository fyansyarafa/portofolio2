# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Jonasyao/Machine-Learning-Specialization-University-of-Washington-/master/Regression/Assignment_four/kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe().columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
X = df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement','sqft_living15', 'sqft_lot15']]
y = df['price']

# %%
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0            3       1.00         1180      5650     1.0           0     0
# 1            3       2.25         2570      7242     2.0           0     0
# 2            2       1.00          770     10000     1.0           0     0
# 3            4       3.00         1960      5000     1.0           0     0
# 4            3       2.00         1680      8080     1.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 3160         3       2.50         1840      8250     1.0           0     1
# 3161         3       1.50         1620      7500     1.0           0     2
# 3162         2       1.50         1840      9000     1.0           0     2
# 3163         3       1.00         1360     73616     1.0           0     0
# 3164         4       1.00         2080      5500     1.0           0     0
#
# ...

# %%
sns.set()
sns.set_style('darkgrid')
sns.pairplot(df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement','sqft_living15', 'sqft_lot15','price']])
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\numpy\lib\histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\User\Anaconda3\lib\site-packages\numpy\lib\histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.distplot(df['price'])

# %%
plt.figure(figsize=(12,7))
ae = sns.heatmap(df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement','sqft_living15', 'sqft_lot15','price']].corr(),annot=True)


bottom, top = ae.get_ylim()
ae.set_ylim(bottom + 0.5, top - 0.5)
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression(normalize=True)

# %%
lm.fit(newwX,newy)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_train.replace([np.inf, -np.inf], np.nan).dropna(axis=1)
# Out:
#           price
# 130    212000.0
# 381    950000.0
# 590    505000.0
# 486   1067000.0
# 1787   552500.0
# ...         ...
# 599   1220000.0
# 1599   455000.0
# 1361  2200000.0
# 1547   503000.0
# 863    910000.0
#
# [2120 rows x 1 columns]

# %%
y_train = pd.DataFrame(y_train)

# %%
np.isfinite(X_train)
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 130       True       True         True      True    True        True  True
# 381       True       True         True      True    True        True  True
# 590       True       True         True      True    True        True  True
# 486       True       True         True      True    True        True  True
# 1787      True       True         True      True    True        True  True
# ...        ...        ...          ...       ...     ...         ...   ...
# 599       True       True         True      True    True        True  True
# 1599      True       True         True      True    True        True  True
# 1361      True       True         True      True    True        True  True
# 1547      True       True         True      True    True        True  True
# 863       True       True         True      True    True        True  True
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3165 entries, 0 to 3164
# Data columns (total 21 columns):
# id               3165 non-null int64
# date             3165 non-null object
# price            3165 non-null float64
# bedrooms         3165 non-null int64
# bathrooms        3165 non-null float64
# sqft_living      3165 non-null int64
# sqft_lot         3165 non-null int64
# floors           3165 non-null float64
# waterfront       3165 non-null int64
# view             3165 non-null int64
# condition        3165 non-null int64
# grade            3165 non-null int64
# sqft_above       3165 non-null int64
# sqft_basement    3165 non-null int64
# yr_built         3165 non-null int64
# yr_renovated     3165 non-null int64
# zipcode          3165 non-null int64
# lat              3165 non-null float64
# long             3165 non-null float64
# sqft_living15    3164 non-null float64
# sqft_lot15       3164 non-null float64
# dtypes: float64(7), int64(13), object(1)
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2120 entries, 130 to 863
# Data columns (total 13 columns):
# bedrooms         2120 non-null int64
# bathrooms        2120 non-null float64
# sqft_living      2120 non-null int64
# sqft_lot         2120 non-null int64
# floors           2120 non-null float64
# waterfront       2120 non-null int64
# view             2120 non-null int64
# condition        2120 non-null int64
# grade            2120 non-null int64
# sqft_above       2120 non-null int64
# sqft_basement    2120 non-null int64
# sqft_living15    2119 non-null float64
# sqft_lot15       2119 non-null float64
# dtypes: float64(4), int64(9)
# memory usage: 231.9 KB

# %%
X_train['bedrooms'].astype(np.float64,)
# Out:
# 130     3.0
# 381     3.0
# 590     3.0
# 486     6.0
# 1787    3.0
#        ...
# 599     4.0
# 1599    4.0
# 1361    5.0
# 1547    3.0
# 863     3.0
# Name: bedrooms, Length: 2120, dtype: float64

# %%
newX=X_train.astype(np.float64)
newy=y_train.astype(np.float64)

# %%
np.finfo(np.float64).max
# Out:
# 1.7976931348623157e+308

# %%
np.isnan(newX).any()
# Out:
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# sqft_living15     True
# sqft_lot15        True
# dtype: bool

# %%
np.isnan(newy).any()
# Out:
# price    False
# dtype: bool

# %%
from sklearn.preprocessing import Imputer

# %%
imp = Imputer(strategy='mean',axis=0)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
imp.fit_transform(newX)
# Out:
# array([[3.00000e+00, 1.75000e+00, 1.06000e+03, ..., 0.00000e+00,
#         1.42000e+03, 7.68000e+03],
#        [3.00000e+00, 3.00000e+00, 4.04000e+03, ..., 1.01000e+03,
#         3.36000e+03, 1.41420e+04],
#        [3.00000e+00, 1.50000e+00, 1.83000e+03, ..., 8.20000e+02,
#         2.45000e+03, 1.65963e+05],
#        ...,
#        [5.00000e+00, 4.25000e+00, 4.64000e+03, ..., 1.78000e+03,
#         3.14000e+03, 1.42000e+04],
#        [3.00000e+00, 2.75000e+00, 1.54000e+03, ..., 3.30000e+02,
#         1.54000e+03, 7.41600e+03],
#        [3.00000e+00, 3.50000e+00, 2.48000e+03, ..., 0.00000e+00,
#         1.98000e+03, 3.20000e+03]])

# %%
X_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 130          3       1.75         1060      7875     1.0           0     0
# 381          3       3.00         4040     14338     2.0           0     0
# 590          3       1.50         1830    217800     1.0           0     0
# 486          6       3.50         4860     11793     2.0           0     0
# 1787         3       1.75         2040      5775     1.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 599          4       2.25         3200     15367     2.0           0     0
# 1599         4       1.00         1340      5800     1.5           0     2
# 1361         5       4.25         4640     22703     2.0           1     4
# 1547         3       2.75         1540      6760     1.0           0     0
# 863          3       3.50         2480      3200     2.0           0     0
#
# ...

# %%
X_train.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
newwX = pd.DataFrame(imp.fit_transform(newX),columns=X_train.columns)

# %%
newwX
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0          3.0       1.75       1060.0    7875.0     1.0         0.0   0.0
# 1          3.0       3.00       4040.0   14338.0     2.0         0.0   0.0
# 2          3.0       1.50       1830.0  217800.0     1.0         0.0   0.0
# 3          6.0       3.50       4860.0   11793.0     2.0         0.0   0.0
# 4          3.0       1.75       2040.0    5775.0     1.0         0.0   0.0
# ...        ...        ...          ...       ...     ...         ...   ...
# 2115       4.0       2.25       3200.0   15367.0     2.0         0.0   0.0
# 2116       4.0       1.00       1340.0    5800.0     1.5         0.0   2.0
# 2117       5.0       4.25       4640.0   22703.0     2.0         1.0   4.0
# 2118       3.0       2.75       1540.0    6760.0     1.0         0.0   0.0
# 2119       3.0       3.50       2480.0    3200.0     2.0         0.0   0.0
#
# ...

# %%
np.isnan(newwX).any()
# Out:
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
lm.intercept_
# Out:
# array([-600929.31853795])

# %%
lm.coef_
# Out:
# array([[-3.79808125e+04, -8.42296317e+03,  8.55293897e+01,
#          6.21935861e-02, -1.56148076e+04,  9.11392004e+05,
#          5.08118088e+04,  4.95298800e+04,  9.08816178e+04,
#          7.62828782e+01,  1.05202202e+02,  4.22978388e+01,
#         -7.41434821e-01]])

# %%
pred = lm.predict(X_test)

# %%
pred
# Out:
# array([[652910.6481199 ],
#        [308428.8781373 ],
#        [472445.97168179],
#        ...,
#        [565196.68482604],
#        [373977.37473785],
#        [399877.34628351]])

# %%
plt.scatter(y_test,pred)

# %%
tb = pd.DataFrame(y_test)

# %%
tb['pred'] = pred

y_test-pred
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-88-3fc827851d67> in <module>
#       1 tb['pred'] = pred
#       2
# ----> 3 y_test-pred
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
# -> 1050             left, result, index=left.index, name=res_name, dtype=None
#    1051         )
#    1052
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _construct_result(left, result, index, name, dtype)
#     917     not be enough; we still need to override the name attribute.
#     918     """
# --> 919     out = left._constructor(result, index=index, dtype=dtype)
#     920     out = out.__finalize__(left)
#     921     out.name = name
#
# ...

# %%
sns.lmplot(y='pred',x='price',data=tb)

# %%
sns.distplot((y_test-pred))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-89-00bde214219e> in <module>
# ----> 1 sns.distplot((y_test-pred))
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
# -> 1050             left, result, index=left.index, name=res_name, dtype=None
#    1051         )
#    1052
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _construct_result(left, result, index, name, dtype)
#     917     not be enough; we still need to override the name attribute.
#     918     """
# --> 919     out = left._constructor(result, index=index, dtype=dtype)
#     920     out = out.__finalize__(left)
#     921     out.name = name
#
# ...

# %%
pred.shape
# Out:
# (1045, 1)

# %%
p = pred.ravel()

# %%
y_test[1519]
# Out:
# 715000.0

# %%
# Out:
# 652910.6481198996

# %%
715000-652910
# Out:
# 62090

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(y_test,pred))
print(metrics.mean_squared_error(y_test,pred))
print(np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# 150901.61678862915
# 63259559978.305176
# 251514.5323401914
